# %%
import pandas as pd
import numpy as np
import pandas as pd 
import re
import os
from datetime import datetime
from collections import Counter
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud ,STOPWORDS, ImageColorGenerator
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import word2vec
import plotly.tools as tls
import plotly.plotly as py
from plotly.offline import init_notebook_mode
import plotly.graph_objs as go
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
sns.set()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
p = "YlGnBu"
p2 = "YlGn"
p3 = "Greys"

# %%
df = pd.read_csv("../input/nyc-jobs.csv")

# %%
df.head()
# Out:
#    Job ID           ...                        Process Date
# 0   87990           ...             2019-06-11T00:00:00.000
# 1   97899           ...             2019-06-11T00:00:00.000
# 2  132292           ...             2019-06-11T00:00:00.000
# 3  132292           ...             2019-06-11T00:00:00.000
# 4  133921           ...             2019-06-11T00:00:00.000
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3159 entries, 0 to 3158
# Data columns (total 28 columns):
# Job ID                           3159 non-null int64
# Agency                           3159 non-null object
# Posting Type                     3159 non-null object
# # Of Positions                   3159 non-null int64
# Business Title                   3159 non-null object
# Civil Service Title              3159 non-null object
# Title Code No                    3159 non-null object
# Level                            3159 non-null object
# Job Category                     3157 non-null object
# Full-Time/Part-Time indicator    2926 non-null object
# Salary Range From                3159 non-null float64
# Salary Range To                  3159 non-null float64
# Salary Frequency                 3159 non-null object
# Work Location                    3159 non-null object
# Division/Work Unit               3159 non-null object
# Job Description                  3159 non-null object
# Minimum Qual Requirements        3146 non-null object
# Preferred Skills                 2770 non-null object
# Additional Information           2001 non-null object
# To Apply                         3158 non-null object
# Hours/Shift                      1012 non-null object
# Work Location 1                  1424 non-null object
# Recruitment Contact              0 non-null float64
# Residency Requirement            3159 non-null object
# Posting Date                     3159 non-null object
# Post Until                       971 non-null object
# Posting Updated                  3159 non-null object
# Process Date                     3159 non-null object
# dtypes: float64(3), int64(2), object(23)
# memory usage: 691.1+ KB

# %% [markdown]
# ## Data cleaning & Feature engineering

# %%
# helper functions
def plot_wordcloud(text):
    wordcloud = WordCloud(background_color='white',
                     width=1024, height=720).generate(text)
    plt.clf()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.show()

def parse_categories(x):
    l = x.replace('&', ',').split(',')
    l = [x.strip().rstrip(',') for x in l]
    key_categories.extend(l)

def parse_keywords(x, l):
    x = x.lower()
    tokens = nltk.word_tokenize(x)
    stop_words = set(stopwords.words('english'))
    token_l = [w for w in tokens if not w in stop_words and w.isalpha()]
    l.extend(token_l)
    
def preferred_skills(x):
    kwl = []
    df[df.job_category==x].preferred_skills.dropna().apply(parse_keywords, l=kwl)
    kwl = pd.Series(kwl)
    return kwl.value_counts()[:20]

# %%
df.drop(['Recruitment Contact', 'Post Until'], axis=1, inplace=True)
df.columns = ['id', 'agency', 'posting_type', 'number_of_positions', 'business_title', 'civil_service_title', 'title_code_number', 'level', 'job_category', 'full-time/part-time', 'salary_range_low', 'salary_range_high', 'salary_frequency', 'work_location', 'work_unit', 'job_description', 'minimum_requirements', 'preferred_skills', 'additional_info', 'to_apply', 'shift', 'work_location_1', 'residency_requirement', 'posting_date', 'posting_updated', 'process_date' ]

# %%
df.job_category.value_counts()
# Out:
# Engineering, Architecture, & Planning                                                                                                                                                                                537
# Technology, Data & Innovation                                                                                                                                                                                        320
# Public Safety, Inspections, & Enforcement                                                                                                                                                                            236
# Health                                                                                                                                                                                                               216
# Legal Affairs                                                                                                                                                                                                        182
# Building Operations & Maintenance                                                                                                                                                                                    174
# Finance, Accounting, & Procurement                                                                                                                                                                                   159
# Constituent Services & Community Programs                                                                                                                                                                            151
# Administration & Human Resources                                                                                                                                                                                     134
# Policy, Research & Analysis                                                                                                                                                                                          108
# Engineering, Architecture, & Planning Public Safety, Inspections, & Enforcement                                                                                                                                       98
# Social Services                                                                                                                                                                                                       63
# Health Public Safety, Inspections, & Enforcement                                                                                                                                                                      57
# Finance, Accounting, & Procurement Policy, Research & Analysis                                                                                                                                                        57
# Health Policy, Research & Analysis                                                                                                                                                                                    48
# Engineering, Architecture, & Planning Policy, Research & Analysis                                                                                                                                                     42
# Communications & Intergovernmental Affairs                                                                                                                                                                            37
# Engineering, Architecture, & Planning Technology, Data & Innovation                                                                                                                                                   35
# Information Technology & Telecommunications                                                                                                                                                                           28
# Policy, Research & Analysis Public Safety, Inspections, & Enforcement                                                                                                                                                 23
# Constituent Services & Community Programs Communications & Intergovernmental Affairs Policy, Research & Analysis                                                                                                      18
# Communications & Intergovernmental Affairs Policy, Research & Analysis                                                                                                                                                17
# Legal Affairs Policy, Research & Analysis                                                                                                                                                                             17
# Engineering, Architecture, & Planning Finance, Accounting, & Procurement                                                                                                                                              15
# Clerical & Administrative Support                                                                                                                                                                                     13
# Building Operations & Maintenance Public Safety, Inspections, & Enforcement                                                                                                                                           13
# Technology, Data & Innovation Policy, Research & Analysis                                                                                                                                                             13
# Administration & Human Resources Policy, Research & Analysis                                                                                                                                                          12
# Constituent Services & Community Programs Communications & Intergovernmental Affairs                                                                                                                                  12
# Constituent Services & Community Programs Building Operations & Maintenance                                                                                                                                           12
#                                                                                                                                                                                                                     ...
# Administration & Human Resources Communications & Intergovernmental Affairs Technology, Data & Innovation                                                                                                              2
# Administration & Human Resources Constituent Services & Community Programs Communications & Intergovernmental Affairs Public Safety, Inspections, & Enforcement                                                        2
# Constituent Services & Community Programs Policy, Research & Analysis                                                                                                                                                  2
# Health Legal Affairs                                                                                                                                                                                                   2
# Administration & Human Resources Communications & Intergovernmental Affairs Finance, Accounting, & Procurement Legal Affairs Public Safety, Inspections, & Enforcement                                                 2
# Communications & Intergovernmental Affairs Health Technology, Data & Innovation                                                                                                                                        2
# Policy & Analysis Social Services                                                                                                                                                                                      2
# Constituent Services & Community Programs Legal Affairs Policy, Research & Analysis Social Services                                                                                                                    2
# Engineering, Architecture, & Planning Maintenance & Operations                                                                                                                                                         2
# Constituent Services & Community Programs Legal Affairs                                                                                                                                                                2
# Engineering, Architecture, & Planning Technology, Data & Innovation Public Safety, Inspections, & Enforcement                                                                                                          2
# Technology, Data & Innovation Social Services                                                                                                                                                                          2
# Administration & Human Resources Finance, Accounting, & Procurement Social Services                                                                                                                                    1
# Administration & Human Resources Communications & Intergovernmental Affairs Legal Affairs                                                                                                                              1
# Administration & Human Resources Technology, Data & Innovation Building Operations & Maintenance                                                                                                                       1
# Administration & Human Resources Constituent Services & Community Programs Social Services                                                                                                                             1
# Clerical & Administrative Support Policy & Analysis                                                                                                                                                                    1
# Administration & Human Resources Constituent Services & Community Programs Communications & Intergovernmental Affairs Building Operations & Maintenance Public Safety, Inspections, & Enforcement Social Services      1
# Constituent Services & Community Programs Engineering, Architecture, & Planning Policy, Research & Analysis Public Safety, Inspections, & Enforcement                                                                  1
# Finance, Accounting, & Procurement Information Technology & Telecommunications                                                                                                                                         1
# Finance, Accounting, & Procurement Policy & Analysis                                                                                                                                                                   1
# Administration & Human Resources Communications & Intergovernmental Affairs Engineering, Architecture, & Planning Policy, Research & Analysis                                                                          1
# Administration & Human Resources Finance, Accounting, & Procurement Public Safety, Inspections, & Enforcement Social Services                                                                                          1
# Finance, Accounting, & Procurement Social Services                                                                                                                                                                     1
# Administration & Human Resources Health Technology, Data & Innovation Building Operations & Maintenance Social Services                                                                                                1
# Administration & Human Resources Constituent Services & Community Programs Technology, Data & Innovation Social Services                                                                                               1
# Administration & Human Resources Health Public Safety, Inspections, & Enforcement                                                                                                                                      1
# Health Building Operations & Maintenance Public Safety, Inspections, & Enforcement                                                                                                                                     1
# Building Operations & Maintenance Public Safety, Inspections, & Enforcement Social Services                                                                                                                            1
# Clerical & Administrative Support Community & Business Services                                                                                                                                                        1
# Name: job_category, Length: 131, dtype: int64

# %% [markdown]
# > - There are many jobs demanding composite skillsets, lets break the composite categories down to single categories and generate a  countplot

# %%
key_categories = []
df.job_category.dropna().apply(parse_categories)
key_categories = pd.Series(key_categories)
key_categories = key_categories[key_categories!='']
popular_categories = key_categories.value_counts().iloc[:25]

# %% [markdown]
# ## Full time or Part time?

# %%
sns.countplot(x='full-time/part-time', data=df, palette=p)

# %% [markdown]
# ## Salary frequency

# %%
sns.countplot(x='salary_frequency', data=df, palette=p2)

# %% [markdown]
# ## Most in-demand job categories

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=key_categories, order=popular_categories.index, palette=p)

# %%
plt.figure(figsize=(10,8))
plot_wordcloud(' '.join(popular_categories.index.tolist()))

# %% [markdown]
# ## Most popular job titles

# %%
plt.figure(figsize=(10,10))
titles_freq = df.civil_service_title.value_counts()
popular_titles = titles_freq.iloc[:25]
sns.countplot(y="civil_service_title", data=df, order=popular_titles.index, palette=p)

# %%
plt.figure(figsize=(10,8))
plot_wordcloud(' '.join(popular_titles.index.tolist()))

# %% [markdown]
# ## Least popular job titles

# %%
least_popular = titles_freq.iloc[-10:]
sns.countplot(y="civil_service_title", data=df, order=least_popular.index, palette=p3)

# %% [markdown]
# ## Jobs with highest low salary range (annual)

# %%
salary_table = df[['civil_service_title', 'salary_range_low', 'salary_range_high']]
jobs_highest_low_range = pd.DataFrame(salary_table.groupby(['civil_service_title'])['salary_range_low'].mean().nlargest(10)).reset_index()
plt.figure(figsize=(8,6))
sns.barplot(y='civil_service_title', x='salary_range_low', data=jobs_highest_low_range, palette=p)

# %% [markdown]
# ## Jobs with highest high salary range (annual)

# %%
jobs_highest_high_range = pd.DataFrame(salary_table.groupby(['civil_service_title'])['salary_range_high'].mean().nlargest(10)).reset_index()
plt.figure(figsize=(8,6))
sns.barplot(y='civil_service_title', x='salary_range_high', data=jobs_highest_high_range, palette=p)

# %% [markdown]
# ## Highest paying jobs on an hourly basis

# %%
hourly_jobs = df[df.salary_frequency == 'Hourly']
jobs_highest_high_range_hourly = pd.DataFrame(hourly_jobs.groupby(['civil_service_title'])['salary_range_high'].mean().nlargest(10)).reset_index()
plt.figure(figsize=(8,6))
sns.barplot(y='civil_service_title', x='salary_range_high', data=jobs_highest_high_range_hourly, palette=p2)

# %%
plt.figure(figsize=(10,8))
plot_wordcloud(' '.join(jobs_highest_high_range_hourly['civil_service_title'].tolist()))

# %% [markdown]
# ## Hourly jobs salary distribution

# %%
sns.distplot(hourly_jobs.salary_range_high)

# %% [markdown]
# ## Popular work units

# %%
popular_divisions = df.work_unit.value_counts().iloc[:10]
sns.countplot(y='work_unit', data=df, order=popular_divisions.index, palette='PuBuGn')

# %% [markdown]
# ## Most common keywords in job descriptions

# %%
job_description_keywords = []
df.job_description.apply(parse_keywords, l=job_description_keywords)
plt.figure(figsize=(10, 8))
counter = Counter(job_description_keywords)
common = [x[0] for x in counter.most_common(40)]
plot_wordcloud(' '.join(common))

# %% [markdown]
# ## Most popular preferred skills per job category

# %%
popular_categories = df.job_category.value_counts()[:5]
popular_categories
# Out:
# Engineering, Architecture, & Planning        537
# Technology, Data & Innovation                320
# Public Safety, Inspections, & Enforcement    236
# Health                                       216
# Legal Affairs                                182
# Name: job_category, dtype: int64

# %%
preferred_skills(popular_categories.index[0]).iplot(title='engineering', kind='bar', color='khaki')
# Out:
# <div>
#
#
#             <div id="f82de1e2-ec79-477f-98cd-1bbf744690b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f82de1e2-ec79-477f-98cd-1bbf744690b1")) {
#                     Plotly.newPlot(
#                         'f82de1e2-ec79-477f-98cd-1bbf744690b1',
#                         [{"marker": {"color": "rgba(240, 230, 140, 0.6)", "line": {"color": "rgba(240, 230, 140, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "0a577710-110c-4bc9-8200-8719b444164a", "x": ["experience", "ability", "skills", "knowledge", "construction", "candidates", "written", "communication", "design", "management", "excellent", "verbal", "work", "microsoft", "project", "strong", "preferred", "must", "projects", "engineering"], "y": [561, 474, 448, 361, 332, 271, 266, 264, 257, 241, 230, 220, 207, 202, 194, 192, 191, 180, 175, 166]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "engineering"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f82de1e2-ec79-477f-98cd-1bbf744690b1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
preferred_skills(popular_categories.index[1]).iplot(title='technology', kind='bar', color='deepskyblue')
# Out:
# <div>
#
#
#             <div id="37368cab-b71e-48d0-affd-d360ebbad9e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("37368cab-b71e-48d0-affd-d360ebbad9e9")) {
#                     Plotly.newPlot(
#                         '37368cab-b71e-48d0-affd-d360ebbad9e9',
#                         [{"marker": {"color": "rgba(0, 191, 255, 0.6)", "line": {"color": "rgba(0, 191, 255, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "6099e346-d56c-4b8f-bfbd-fa57de66143d", "x": ["experience", "ability", "skills", "knowledge", "strong", "security", "management", "years", "development", "working", "communication", "sql", "excellent", "microsoft", "technical", "work", "data", "applications", "including", "business"], "y": [1211, 595, 554, 449, 350, 289, 287, 280, 234, 233, 216, 205, 202, 196, 190, 189, 185, 180, 174, 174]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "technology"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('37368cab-b71e-48d0-affd-d360ebbad9e9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
preferred_skills(popular_categories.index[2]).iplot(title='public safety', kind='bar', color='green')
# Out:
# <div>
#
#
#             <div id="8ae5a84e-c52e-4b94-bd4d-fec47882bf9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8ae5a84e-c52e-4b94-bd4d-fec47882bf9f")) {
#                     Plotly.newPlot(
#                         '8ae5a84e-c52e-4b94-bd4d-fec47882bf9f',
#                         [{"marker": {"color": "rgba(0, 128, 0, 0.6)", "line": {"color": "rgba(0, 128, 0, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "7e1eeb08-6916-4649-a873-4338c054e730", "x": ["ability", "experience", "skills", "work", "strong", "knowledge", "excellent", "must", "communication", "new", "york", "years", "manage", "computer", "demonstrated", "law", "including", "working", "excel", "enforcement"], "y": [344, 264, 236, 114, 113, 112, 89, 83, 83, 80, 79, 76, 72, 70, 67, 67, 65, 64, 64, 63]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "public safety"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8ae5a84e-c52e-4b94-bd4d-fec47882bf9f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
preferred_skills(popular_categories.index[3]).iplot(title='health', kind='bar', color='powderblue')
# Out:
# <div>
#
#
#             <div id="326e5c16-2b0b-4479-af0c-3ee79ae14e42" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("326e5c16-2b0b-4479-af0c-3ee79ae14e42")) {
#                     Plotly.newPlot(
#                         '326e5c16-2b0b-4479-af0c-3ee79ae14e42',
#                         [{"marker": {"color": "rgba(176, 224, 230, 0.6)", "line": {"color": "rgba(176, 224, 230, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "39997316-2653-4d91-8c31-347706afdff5", "x": ["experience", "skills", "ability", "excellent", "health", "knowledge", "communication", "interpersonal", "work", "working", "public", "must", "strong", "new", "york", "including", "written", "license", "state", "computer"], "y": [188, 182, 105, 94, 84, 82, 79, 62, 60, 52, 50, 48, 48, 47, 41, 41, 40, 38, 37, 37]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "health"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('326e5c16-2b0b-4479-af0c-3ee79ae14e42');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
preferred_skills(popular_categories.index[4]).iplot(title='legal affairs', kind='bar', color='darkolivegreen')
# Out:
# <div>
#
#
#             <div id="ce7a3453-fac8-46e3-8c96-05072815ef00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ce7a3453-fac8-46e3-8c96-05072815ef00")) {
#                     Plotly.newPlot(
#                         'ce7a3453-fac8-46e3-8c96-05072815ef00',
#                         [{"marker": {"color": "rgba(85, 107, 47, 0.6)", "line": {"color": "rgba(85, 107, 47, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "8f0ed518-6da4-4040-9702-4c381372ecac", "x": ["skills", "experience", "people", "ability", "strong", "excellent", "work", "communication", "legal", "written", "writing", "law", "knowledge", "must", "city", "preferred", "organizational", "oral", "new", "years"], "y": [306, 220, 154, 140, 139, 114, 103, 101, 88, 60, 60, 60, 58, 57, 57, 56, 56, 55, 49, 49]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "legal affairs"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ce7a3453-fac8-46e3-8c96-05072815ef00');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Minimum Qualification Wordcloud

# %%
qualification_keywords = []
df.minimum_requirements.dropna().apply(parse_keywords, l=qualification_keywords)
plt.figure(figsize=(10, 8))
counter = Counter(qualification_keywords)
common = [x[0] for x in counter.most_common(40)]
plot_wordcloud(' '.join(common))
