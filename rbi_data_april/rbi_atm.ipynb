# %%
import pandas as pd
import  numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('rbi_atm_april.XLSX')

# %%
df.head(10)
# Out:
#                Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 5          ALLAHABAD BANK        761        196       3116          0
# 6             ANDHRA BANK       3023        773      13777          0
# 7          BANK OF BARODA       9321       3850      78791          0
# 8           BANK OF INDIA       2645       3509      67740          0
# 9     BANK OF MAHARASHTRA       1306        554       2350          0
# 10            CANARA BANK       4760       4077      21910          0
# 11  CENTRAL BANK OF INDIA       2668        896       3384          0
# 12       CORPORATION BANK       2414        629     222811          0
# 13            INDIAN BANK       3198        696      10938          0
# 14   INDIAN OVERSEAS BANK       2688        395      19750          0
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 5           0          0          0           0           0     5910582
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 1', axis=1, inplace=True)

# %%
df = df.drop(df.index[[0,1,2,3,4]])
df = df.drop(df.index[66:])

# %%
df.index = range(0, 66)              # Index runs from 0 to 66

columns = ['Bank Name', 'ATMs Onsite', 'ATMs Offsite', 'POS Online', 'POS Offline', 'Credits cards outstanding at the end of the month', 'CC No. of transactions ATM',
           'CC No. of transactions POS', 'CC Amount of transactions ATM', 'CC Amount of transactions POS', 'Debits cards outstanding at the end of the month', 'DC No. of transactions ATM', 'DC No. of transactions POS', 
           'DC Amount of transactions ATM', 'DC Amount of transactions POS']          
                                    #Columns are named

df.columns = columns

# %%
df.head(10)
# Out:
#                Bank Name  ATMs Onsite  ATMs Offsite  POS Online  POS Offline  \
# 0         ALLAHABAD BANK        761.0         196.0      3116.0          0.0
# 1            ANDHRA BANK       3023.0         773.0     13777.0          0.0
# 2         BANK OF BARODA       9321.0        3850.0     78791.0          0.0
# 3          BANK OF INDIA       2645.0        3509.0     67740.0          0.0
# 4    BANK OF MAHARASHTRA       1306.0         554.0      2350.0          0.0
# 5            CANARA BANK       4760.0        4077.0     21910.0          0.0
# 6  CENTRAL BANK OF INDIA       2668.0         896.0      3384.0          0.0
# 7       CORPORATION BANK       2414.0         629.0    222811.0          0.0
# 8            INDIAN BANK       3198.0         696.0     10938.0          0.0
# 9   INDIAN OVERSEAS BANK       2688.0         395.0     19750.0          0.0
#
#    Credits cards outstanding at the end of the month  \
# 0                                                0.0
# ...

# %%
for i in df.columns[1:]:
    df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 15 columns):
# Bank Name                                            65 non-null object
# ATMs Onsite                                          65 non-null float64
# ATMs Offsite                                         65 non-null float64
# POS Online                                           65 non-null float64
# POS Offline                                          65 non-null float64
# Credits cards outstanding at the end of the month    65 non-null float64
# CC No. of transactions ATM                           65 non-null float64
# CC No. of transactions POS                           65 non-null float64
# CC Amount of transactions ATM                        65 non-null float64
# CC Amount of transactions POS                        65 non-null float64
# Debits cards outstanding at the end of the month     65 non-null float64
# ...

# %%
df.drop('POS Offline', axis=1, inplace=True)

# %%
df.to_csv('April 19.csv')
