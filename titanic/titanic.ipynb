# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(df.isnull(), cmap='viridis', yticklabels=False)

# %%
sns.boxplot(x='Pclass', y='Age', data=df)

# %%
def fill_age(cols):
    pclass = cols[0]
    age = cols[1]
    if pd.isnull(age):
        if pclass == 1 :
            return 37
        elif pclass == 2:
            return 30
        else:
            return 24
    else:
        return age

# %%
df['Age'] = df[['Pclass', 'Age']].apply(fill_age, axis=1)
df.drop('Cabin', axis=1, inplace=True)

# %%
sns.heatmap(df.isnull(), cmap='viridis', yticklabels=False)

# %%
sex = pd.get_dummies(df['Sex'],drop_first=True)
embark = pd.get_dummies(df['Embarked'],drop_first=True)

# %%
df.drop(['Sex', 'Embarked', 'Name', 'Ticket'], axis=1, inplace=True)

# %%
df = pd.concat([df,sex,embark], axis=1)

# %%
df_test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          892       3  34.5      0      0   7.8292     1  1  0
# 1          893       3  47.0      1      0   7.0000     0  0  1
# 2          894       2  62.0      0      0   9.6875     1  1  0
# 3          895       3  27.0      0      0   8.6625     1  0  1
# 4          896       3  22.0      1      1  12.2875     0  0  1

# %%
df.drop("PassengerId", axis=1, inplace=True)

# %%
X = df.drop('Survived', axis=1)

# %%
y = df['Survived']

# %%
X_test = df_test

# %%
X_test
X
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 0         3  22.0      1      0    7.2500     1  0  1
# 1         1  38.0      1      0   71.2833     0  0  0
# 2         3  26.0      0      0    7.9250     0  0  1
# 3         1  35.0      1      0   53.1000     0  0  1
# 4         3  35.0      0      0    8.0500     1  0  1
# 5         3  24.0      0      0    8.4583     1  1  0
# 6         1  54.0      0      0   51.8625     1  0  1
# 7         3   2.0      3      1   21.0750     1  0  1
# 8         3  27.0      0      2   11.1333     0  0  1
# 9         2  14.0      1      0   30.0708     0  0  0
# 10        3   4.0      1      1   16.7000     0  0  1
# 11        1  58.0      0      0   26.5500     0  0  1
# 12        3  20.0      0      0    8.0500     1  0  1
# 13        3  39.0      1      5   31.2750     1  0  1
# 14        3  14.0      0      0    7.8542     0  0  1
# 15        2  55.0      0      0   16.0000     0  0  1
# ...

# %%
X_train.head()
# Out:
#      Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 520       1  30.0      0      0  93.5000     0  0  1
# 510       3  29.0      0      0   7.7500     1  1  0
# 446       2  13.0      0      1  19.5000     0  0  1
# 2         3  26.0      0      0   7.9250     0  0  1
# 691       3   4.0      0      1  13.4167     0  0  0

# %%
y_train.head()
# Out:
# 520    1
# 510    1
# 446    1
# 2      1
# 691    1
# Name: Survived, dtype: int64

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          892       3  34.5      0      0   7.8292     1  1  0
# 1          893       3  47.0      1      0   7.0000     0  0  1
# 2          894       2  62.0      0      0   9.6875     1  1  0
# 3          895       3  27.0      0      0   8.6625     1  0  1
# 4          896       3  22.0      1      1  12.2875     0  0  1

# %%
df_test['Age'] = df_test[['Pclass', 'Age']].apply(fill_age, axis=1)
df_test.drop('Cabin', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-cb7887fa6f9f> in <module>
#       1 df_test['Age'] = df_test[['Pclass', 'Age']].apply(fill_age, axis=1)
# ----> 2 df_test.drop('Cabin', axis=1, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
sex = pd.get_dummies(df_test['Sex'],drop_first=True)
embark = pd.get_dummies(df_test['Embarked'],drop_first=True)

# %%
df_test.drop(['Sex', 'Embarked', 'Name', 'Ticket'], axis=1, inplace=True)

# %%
df_test = pd.concat([df_test, sex, embark], axis=1)

# %%
sns.heatmap(df_test.isnull(), cmap='viridis', yticklabels=False)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, y_train)
# Out:
# C:\Users\PUNAM\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
preds = logreg.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-7e649f392834> in <module>
# ----> 1 preds = logreg.predict(df_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     263                                  "yet" % {'name': type(self).__name__})
#     264
# --> 265         X = check_array(X, accept_sparse='csr')
#     266
#     267         n_features = self.coef_.shape[1]
#
# ...

# %%
testset = pd.read_csv('test.csv')

# %%
testset.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
testset.drop('Cabin', axis=1, inplace=True)

# %%
sns.boxplot(x='Pclass', y='Age', data=testset)

# %%
def fill_age(cols):
    pclass = cols[0]
    age = cols[1]
    if pd.isnull(age):
        if pclass == 1 :
            return 42
        elif pclass == 2:
            return 28
        else:
            return 25
    else:
        return age

# %%
testset['Age'] = testset[['Pclass', 'Age']].apply(fill_age, axis=1)

# %%
testset.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          892       3  34.5      0      0   7.8292     1  1  0
# 1          893       3  47.0      1      0   7.0000     0  0  1
# 2          894       2  62.0      0      0   9.6875     1  1  0
# 3          895       3  27.0      0      0   8.6625     1  0  1
# 4          896       3  22.0      1      1  12.2875     0  0  1

# %%
sex = pd.get_dummies(testset['Sex'],drop_first=True)
embark = pd.get_dummies(testset['Embarked'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-cd305895fceb> in <module>
# ----> 1 sex = pd.get_dummies(testset['Sex'],drop_first=True)
# ...

# %%
testset.drop(['Sex', 'Embarked', 'Name', 'Ticket'], axis=1, inplace=True)

# %%
testset = pd.concat([testset, sex, embark], axis=1)

# %%
testset.drop('PassengerId', axis=1, inplace =True)

# %%
testset.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'Q',
#        'S'],
#       dtype='object')

# %%
y_train.head()
# Out:
# 520    1
# 510    1
# 446    1
# 2      1
# 691    1
# Name: Survived, dtype: int64

# %%
preds = logreg.predict(testset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-62d0b27a8f13> in <module>
# ----> 1 preds = logreg.predict(testset)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     263                                  "yet" % {'name': type(self).__name__})
#     264
# --> 265         X = check_array(X, accept_sparse='csr')
#     266
#     267         n_features = self.coef_.shape[1]
#
# ...

# %%
sns.heatmap(testset.isnull(), cmap='viridis', yticklabels=False)
